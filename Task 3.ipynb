# %% [markdown]
# ### 1. Create a issue
#
# <br>
# <img src = "images/Screenshot 2022-10-05 at 6.02.18 PM.png">
# <br>
#
# ``` Issue Created issue another account```
#
# ### 2. Raise a pull request
#
# <br>
# <img src = "images/Screenshot 2022-10-05 at 5.50.57 PM.png">
# <br>
#
# ```raised a pull request from another account.```
#
# ### 3. Merge a Pull request
#
# <br>
# <img src = "images/Screenshot 2022-10-05 at 6.01.18 PM.png">
# <br>
#
# ```merged pull request raised by another account.```
#
# ### 4. Reject a pull request
#
# <br>
# <img src = "images/Screenshot 2022-10-05 at 6.08.30 PM.png">
# <br>
#
# <br>
# <img src = "images/Screenshot 2022-10-05 at 6.09.03 PM.png">
# <br>
#
# ``` rejected a pull request with proper comments. Closed PR after reviewing codes.```
#
# ### 5. stash changes
#
# <br>
# <img src = "images/Screenshot 2022-10-05 at 6.50.02 PM.png">
# <br>
#
# <br>
# <img src = "images/Screenshot 2022-10-05 at 7.04.14 PM.png">
# <br>
#
# ``` Changes Stashed and merged into branch main. ```
#
# ### 6. Add a Dependabot alerts in your github
#
# <br>
# <img src = "images/Screenshot 2022-10-05 at 5.56.58 PM.png">
# <br>
#
# ``` Added Dependabot for pull requests.```
#
# ### 7. Create a release --
#
# ``` release setup is also done for this repo```
#
# ### 8. Setup a Projects Board for your project.
#
# ``` Setup board is also created.```
